# %% [markdown]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Hash Table Endpoint Demo\n",
#     "This notebook calls your FastAPI Hash Table endpoint.\n",
#     "We’ll insert and retrieve key–value pairs."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import requests\n",
#     "\n",
#     "# Insert key-value pairs\n",
#     "insert_payload = {\"key\": \"alpha\", \"value\": 42}\n",
#     "requests.post('http://localhost:8000/hash_table/insert', json=insert_payload)\n",
#     "\n",
#     "insert_payload = {\"key\": \"beta\", \"value\": 99}\n",
#     "requests.post('http://localhost:8000/hash_table/insert', json=insert_payload)\n",
#     "\n",
#     "# Retrieve a value by key\n",
#     "response = requests.get('http://localhost:8000/hash_table/get?key=alpha')\n",
#     "response.json()"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "✅ Expected result: `{ \"value\": 42 }` when retrieving key `alpha`."
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   },
#   "language_info": {
#    "name": "python",
#    "version": "3.10"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
