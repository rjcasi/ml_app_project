# %% [markdown]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Gamma Function Demo\n",
#     "This notebook demonstrates how to call the Gamma endpoint from the ML App Project API."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import requests\n",
#     "\n",
#     "# Base URL (adjust if running locally vs Codespaces)\n",
#     "BASE_URL = \"http://127.0.0.1:8000\"\n",
#     "\n",
#     "# Call the Gamma endpoint\n",
#     "response = requests.get(f\"{BASE_URL}/special/gamma_function\", params={\"z\": 5})\n",
#     "response.json()"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "You should see output like:\n",
#     "```json\n",
#     "{\n",
#     "  \"input\": 5,\n",
#     "  \"Gamma(z)\": 24.0\n",
#     "}\n",
#     "```\n",
#     "Since Γ(5) = 4! = 24."
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   },
#   "language_info": {
#    "name": "python",
#    "version": "3.12"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 2
# }
