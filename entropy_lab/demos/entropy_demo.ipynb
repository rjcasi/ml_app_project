# %%
# If entropy_lab is in the same folder as your notebook
import sys, os
sys.path.append("/mnt/c/Users/rjcas/ml_api_project") # or the relative path to your lab folder

from entropy_lab import entropy_core
from entropy_lab import shannon_entropy

# Example: run Shannon entropy on a dataset
data = [0,1,1,0,1,0,0,1]
entropy_value = entropy_core.shannon_entropy(data)
print("Entropy:", entropy_value)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 import sys, os
#       3 sys.path.append("/mnt/c/Users/rjcas/ml_api_project") # or the relative path to your lab folder
# ----> 5 from entropy_lab import entropy_core
#       6 from entropy_lab import shannon_entropy
#       8 # Example: run Shannon entropy on a dataset
#
# ModuleNotFoundError: No module named 'entropy_lab'

# %%
import matplotlib.pyplot as plt
plt.plot(range(len(data)), data)
plt.title("Entropy Input Stream")
plt.show()
import ipywidgets as widgets
widgets.IntSlider(min=1, max=100, step=1, value=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(range(len(data)), data)
#       3 plt.title("Entropy Input Stream")
#       4 plt.show()
#
# NameError: name 'data' is not defined
